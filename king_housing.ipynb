# %% [markdown]
# #  *** Predicting the housing price! ***
# ##### Author: Fang (Colin) Shu
# ##### Date: 05/24/19

# %% [markdown]
# # Import all the package for data analysis

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
unit = pd.read_csv('UnitBreakdown.csv')

# %%
unit.head()
# Out:
#     Major  Minor  UnitTypeItemId  NbrThisType  SqFt NbrBedrooms  NbrBaths
# 0   82605   9206               1           29   813           0       1.0
# 1  722850   2420               1            1     0           5       2.0
# 2  292605   9021               1           51  1165           3       2.0
# 3  182604   9228               1           10     0           1       1.0
# 4  720000    201               1           12   750           1       1.0

# %%
unit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24635 entries, 0 to 24634
# Data columns (total 7 columns):
# Major             24635 non-null int64
# Minor             24635 non-null int64
# UnitTypeItemId    24635 non-null int64
# NbrThisType       24635 non-null int64
# SqFt              24635 non-null int64
# NbrBedrooms       24626 non-null object
# NbrBaths          24635 non-null float64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 1.3+ MB

# %%
price = pd.read_csv('RPSale.csv')
# Out:
# /Applications/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,2) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2023223 entries, 0 to 2023222
# Data columns (total 24 columns):
# ExciseTaxNbr          int64
# Major                 object
# Minor                 object
# DocumentDate          object
# SalePrice             int64
# RecordingNbr          object
# Volume                object
# Page                  object
# PlatNbr               object
# PlatType              object
# PlatLot               object
# PlatBlock             object
# SellerName            object
# BuyerName             object
# PropertyType          int64
# PrincipalUse          int64
# SaleInstrument        int64
# AFForestLand          object
# AFCurrentUseLand      object
# AFNonProfitUse        object
# AFHistoricProperty    object
# SaleReason            int64
# PropertyClass         int64
# SaleWarning           object
# dtypes: int64(7), object(17)
# memory usage: 370.5+ MB

# %%
price

# %%
price_only_2018 = price[price['DocumentDate'].str.endswith('2018')]

# %%
price.head()
# Out:
#    ExciseTaxNbr   Major Minor DocumentDate  SalePrice    RecordingNbr Volume  \
# 0       2687551  138860   110   08/21/2014     245000  20140828001436
# 1       1235111  664885    40   07/09/1991          0  199203161090      071
# 2       2704079  423943    50   10/11/2014          0  20141205000558
# 3       2584094  403700   715   01/04/2013          0  20130110000910
# 4       1056831  951120   900   04/20/1989      85000  198904260448      117
#
#   Page PlatNbr PlatType     ...     PropertyType PrincipalUse SaleInstrument  \
# 0                           ...                3            6              3
# 1  001  664885        C     ...                3            0             26
# 2                           ...                3            6             15
# 3                           ...                3            6             15
# 4  053  951120        P     ...                3            0              2
#
#   AFForestLand  AFCurrentUseLand  AFNonProfitUse  AFHistoricProperty  \
# 0            N                 N               N                   N
# 1            N                 N               N                   N
# 2            N                 N               N                   N
# 3            N                 N               N                   N
# 4            N                 N               N                   N
#
#   SaleReason PropertyClass SaleWarning
# 0          1             8
# 1         18             3          11
# 2         18             8    18 31 51
# 3         11             8    18 31 38
# 4          1             9          49
#
# [5 rows x 24 columns]

# %%
waterf = pd.read_csv('Parcel.csv',encoding ='latin-1')

# %%
waterf.head()
# Out:
#     Major  Minor                  PropName              PlatName  \
# 0   42105   9040                                             NaN
# 1  803540    320                                       STONEGATE
# 2   52406   9057                                             NaN
# 3  113730    520                            BROOK TRAILS ESTATES
# 4  932090    240  WESTWAY (TOWNHOUSE PLAT)               WESTWAY
#
#           PlatLot PlatBlock  Range  Township  Section QuarterSection  \
# 0                                5        21        4             NE
# 1  32                            5        23        3             NE
# 2                                6        24        5             NE
# 3  52                            6        26       18             SW
# 4  24                            3        21       13             SE
#
#        ...       SeismicHazard  LandslideHazard  SteepSlopeHazard  Stream  \
# 0      ...                   N                N                 N       N
# 1      ...                   N                N                 N       N
# 2      ...                   N                N                 N       N
# 3      ...                   N                N                 N       N
# 4      ...                   N                N                 N       N
#
#    Wetland SpeciesOfConcern  SensitiveAreaTract WaterProblems  \
# 0        N                N                   N             N
# 1        N                N                   N             N
# 2        N                N                   N             N
# 3        N                N                   N             N
# 4        N                N                   N             N
#
#    TranspConcurrency  OtherProblems
# 0                  N              N
# 1                  N              N
# 2                  N              N
# 3                  N              N
# 4                  N              N
#
# [5 rows x 81 columns]

# %%
waterf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 612445 entries, 0 to 612444
# Data columns (total 81 columns):
# Major                     612445 non-null int64
# Minor                     612445 non-null int64
# PropName                  600539 non-null object
# PlatName                  518078 non-null object
# PlatLot                   612445 non-null object
# PlatBlock                 612445 non-null object
# Range                     612445 non-null int64
# Township                  612445 non-null int64
# Section                   612445 non-null int64
# QuarterSection            612445 non-null object
# PropType                  612445 non-null object
# Area                      612430 non-null float64
# SubArea                   612430 non-null float64
# SpecArea                  17429 non-null float64
# SpecSubArea               17429 non-null float64
# DistrictName              612445 non-null object
# LevyCode                  612445 non-null int64
# CurrentZoning             612444 non-null object
# HBUAsIfVacant             612445 non-null int64
# HBUAsImproved             612445 non-null int64
# PresentUse                612445 non-null int64
# SqFtLot                   612445 non-null int64
# WaterSystem               612445 non-null int64
# SewerSystem               612445 non-null int64
# Access                    612445 non-null int64
# Topography                612445 non-null int64
# StreetSurface             612445 non-null int64
# RestrictiveSzShape        612445 non-null int64
# InadequateParking         612445 non-null int64
# PcntUnusable              612445 non-null int64
# Unbuildable               612445 non-null bool
# MtRainier                 612445 non-null int64
# Olympics                  612445 non-null int64
# Cascades                  612445 non-null int64
# Territorial               612445 non-null int64
# SeattleSkyline            612445 non-null int64
# PugetSound                612445 non-null int64
# LakeWashington            612445 non-null int64
# LakeSammamish             612445 non-null int64
# SmallLakeRiverCreek       612445 non-null int64
# OtherView                 612445 non-null int64
# WfntLocation              612445 non-null int64
# WfntFootage               612445 non-null int64
# WfntBank                  612445 non-null int64
# WfntPoorQuality           612445 non-null int64
# WfntRestrictedAccess      612445 non-null int64
# WfntAccessRights          612445 non-null object
# WfntProximityInfluence    612445 non-null object
# TidelandShoreland         612445 non-null int64
# LotDepthFactor            612445 non-null int64
# TrafficNoise              612445 non-null int64
# AirportNoise              612445 non-null int64
# PowerLines                612445 non-null object
# OtherNuisances            612445 non-null object
# NbrBldgSites              612445 non-null int64
# Contamination             612445 non-null int64
# DNRLease                  612445 non-null object
# AdjacentGolfFairway       612445 non-null object
# AdjacentGreenbelt         612445 non-null object
# HistoricSite              612445 non-null int64
# CurrentUseDesignation     612445 non-null int64
# NativeGrowthProtEsmt      612445 non-null object
# Easements                 612445 non-null object
# OtherDesignation          612445 non-null object
# DeedRestrictions          612445 non-null object
# DevelopmentRightsPurch    612445 non-null object
# CoalMineHazard            612445 non-null object
# CriticalDrainage          612445 non-null object
# ErosionHazard             612445 non-null object
# LandfillBuffer            612445 non-null object
# HundredYrFloodPlain       612445 non-null object
# SeismicHazard             612445 non-null object
# LandslideHazard           612445 non-null object
# SteepSlopeHazard          612445 non-null object
# Stream                    612445 non-null object
# Wetland                   612445 non-null object
# SpeciesOfConcern          612445 non-null object
# SensitiveAreaTract        612445 non-null object
# WaterProblems             612445 non-null object
# TranspConcurrency         612445 non-null object
# OtherProblems             612445 non-null object
# dtypes: bool(1), float64(4), int64(41), object(35)
# memory usage: 374.4+ MB

# %% [markdown]
# # To merge into a single dataframe, the type of the columns we merge on ('Major' and 'Minor') should be the same.

# %%
price['Major'] = pd.to_numeric(price['Major'],errors='coerce')
price['Minor'] = pd.to_numeric(price['Minor'],errors='coerce')
price['Major'] = price['Major'].dropna()
price['Minor'] = price['Minor'].dropna()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Applications/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    3102             return self._engine.get_value(s, k,
# -> 3103                                           tz=getattr(series.dtype, 'tz', None))
#    3104         except KeyError as e1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index._bin_search()
#
# TypeError: '<' not supported between instances of 'numpy.ndarray' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# <ipython-input-58-78879eae9695> in <module>()
# ----> 1 price['Major'] = pd.to_numeric(price['Major'],errors='coerce')
#       2 # price['Minor'] = pd.to_numeric(price['Minor'],errors='coerce')
#
# /Applications/anaconda3/lib/python3.6/site-packages/pandas/core/series.py in __getitem__(self, key)
#     764         key = com._apply_if_callable(key, self)
#     765         try:
# --> 766             result = self.index.get_value(self, key)
#     767
#     768             if not is_scalar(result):
#
# /Applications/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    3121             # python 3
#    3122             if is_scalar(key):  # pragma: no cover
# -> 3123                 raise IndexError(key)
#    3124             raise InvalidIndexError(key)
#    3125
#
# IndexError: Major

# %%
price['Major'].astype('int64')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-7817093ac641> in <module>()
# ----> 1 price['Major'].astype('int64')
#
# /Applications/anaconda3/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     175                 else:
#     176                     kwargs[new_arg_name] = new_arg_value
# --> 177             return func(*args, **kwargs)
#     178         return wrapper
#     179     return _deprecate_kwarg
#
# /Applications/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4995             # else, only a single dtype is given
#    4996             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 4997                                          **kwargs)
#    4998             return self._constructor(new_data).__finalize__(self)
#    4999
#
# /Applications/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in astype(self, dtype, **kwargs)
#    3712
#    3713     def astype(self, dtype, **kwargs):
# -> 3714         return self.apply('astype', dtype=dtype, **kwargs)
#    3715
#    3716     def convert(self, **kwargs):
#
# /Applications/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#    3579
#    3580             kwargs['mgr'] = self
# -> 3581             applied = getattr(b, f)(**kwargs)
#    3582             result_blocks = _extend_blocks(applied, result_blocks)
#    3583
#
# /Applications/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in astype(self, dtype, copy, errors, values, **kwargs)
#     573     def astype(self, dtype, copy=False, errors='raise', values=None, **kwargs):
#     574         return self._astype(dtype, copy=copy, errors=errors, values=values,
# --> 575                             **kwargs)
#     576
#     577     def _astype(self, dtype, copy=False, errors='raise', values=None,
#
# /Applications/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in _astype(self, dtype, copy, errors, values, klass, mgr, **kwargs)
#     662
#     663                 # _astype_nansafe works fine with 1-d only
# --> 664                 values = astype_nansafe(values.ravel(), dtype, copy=True)
#     665                 values = values.reshape(self.shape)
#     666
#
# /Applications/anaconda3/lib/python3.6/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy)
#     707         # work around NumPy brokenness, #1987
#     708         if np.issubdtype(dtype.type, np.integer):
# --> 709             return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
#     710
#     711         # if we have a datetime/timedelta array of objects
#
# pandas/_libs/lib.pyx in pandas._libs.lib.astype_intsafe()
#
# pandas/_libs/src/util.pxd in util.set_value_at_unsafe()
#
# ValueError: invalid literal for int() with base 10: '      '

# %%
price.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-59-e428b4d6b629> in <module>()
# ----> 1 price.info()
#
# /Applications/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'info'

# %%
price['Major'].value_counts().sort_values()
# Out:
# 197020       1
# 125370       1
# 732771       1
# 319650       1
# 067600       1
# 388833       1
# 866313       1
# 443260       1
# 250900       1
# 376321       1
# 141978       1
# 045800       1
# 269680       1
# 216140       1
# 889250       1
# 390495       1
# 505230       1
# 228400       1
# 694000       1
# 383093       1
# 930650       1
# 953440       1
# 792350       1
# 377930       1
# 752557       1
# 502750       1
# 172409       1
# 124620       1
# 721590       1
# 306310       1
#           ...
# 952810    1804
# 766620    1813
# 334210    1873
# 125020    1885
# 982870    1894
# 137080    1941
# 357530    1991
# 118000    2001
# 124500    2098
# 95200     2103
# 712930    2136
# 335640    2216
# 52407     2257
# 408330    2351
# 276770    2377
# 797260    2454
# 751850    2490
# 788360    2507
# 375060    2586
# 388580    2630
# 197220    2687
# 762570    2954
# 537980    3297
# 277060    3712
# 154580    3757
# 510140    4018
# 276760    4101
# 343850    4161
# 375160    4690
# 0         9345
# Name: Major, Length: 28624, dtype: int64

# %%
to_drop = price[str(type(price['Major']))!='int64']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Applications/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: True
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-2a2a168c4fd5> in <module>()
# ----> 1 to_drop = price[str(type(price['Major']))!='int64']
#
# /Applications/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2683             return self._getitem_multilevel(key)
#    2684         else:
# -> 2685             return self._getitem_column(key)
#    2686
#    2687     def _getitem_column(self, key):
#
# /Applications/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2690         # get column
#    2691         if self.columns.is_unique:
# -> 2692             return self._get_item_cache(key)
#    2693
#    2694         # duplicate columns & possible reduce dimensionality
#
# /Applications/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    2484         res = cache.get(item)
#    2485         if res is None:
# -> 2486             values = self._data.get(item)
#    2487             res = self._box_item_values(item, values)
#    2488             cache[item] = res
#
# /Applications/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /Applications/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
# -> 3065                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3066
#    3067         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: True

# %%
price[['Major','Minor']].value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-af7beefc3ad1> in <module>()
# ----> 1 price[['Major','Minor']].value_counts()
#
# /Applications/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'value_counts'

# %%
housing = pd.merge(unit,price,on=['Major','Minor'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-7d0248cd5c53> in <module>()
# ----> 1 housing = pd.merge(unit,price,on=['Major','Minor'])
#
# /Applications/anaconda3/lib/python3.6/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      58                          right_index=right_index, sort=sort, suffixes=suffixes,
#      59                          copy=copy, indicator=indicator,
# ---> 60                          validate=validate)
#      61     return op.get_result()
#      62
#
# /Applications/anaconda3/lib/python3.6/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     552         # validate the merge keys dtypes. We may need to coerce
#     553         # to avoid incompat dtypes
# --> 554         self._maybe_coerce_merge_keys()
#     555
#     556         # If argument passed to validate,
#
# /Applications/anaconda3/lib/python3.6/site-packages/pandas/core/reshape/merge.py in _maybe_coerce_merge_keys(self)
#     976             # incompatible dtypes GH 9780, GH 15800
#     977             elif is_numeric_dtype(lk) and not is_numeric_dtype(rk):
# --> 978                 raise ValueError(msg)
#     979             elif not is_numeric_dtype(lk) and is_numeric_dtype(rk):
#     980                 raise ValueError(msg)
#
# ValueError: You are trying to merge on int64 and object columns. If you wish to proceed you should use pd.concat
